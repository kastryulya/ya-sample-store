# %%
# %pip install pymysql==1.0.2
# %pip install SQLAlchemy==1.4.46

# %%
import pymysql as MySQLdb
from sqlalchemy import create_engine

import pandas as pd

# %%
# engine = create_engine('mysql+pymysql://magento-svc:m%40gent0@10.128.0.18/ya_sample_store?charset=utf8')

host = "10.128.0.18"
db_name = "ya_sample_store"
username = "magento-svc"
password = "m%40gent0"
engine = create_engine('mysql://{username}:{password}@{url}/{db_name}?charset=utf8'
                        .format(username=username, password=password,
                                url=host, db_name=db_name), echo=False)

# %%
data = pd.read_sql('select * from ya_sample_store.user_payments limit 10', engine)

# %%
print(data)
